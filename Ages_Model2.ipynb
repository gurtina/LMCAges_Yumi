# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import gridspec
from matplotlib.colors import LogNorm
from copy import copy

# %%
LMCpos1 = np.loadtxt('LMC_StarsPos_Model1.txt')
LMCage1 = np.loadtxt('LMC_StarsAge_Model1.txt')

# %%
LMCpos2 = np.loadtxt('LMC_StarsPos_Model2.txt')
LMCage2 = np.loadtxt('LMC_StarsAge_Model2.txt')

# %%
SMCpos1 = np.loadtxt('SMC_StarsPos_Model1.txt')
SMCage1 = np.loadtxt('SMC_StarsAge_Model1.txt')

# %%
SMCpos2 = np.loadtxt('SMC_StarsPos_Model1.txt')
SMCage2 = np.loadtxt('SMC_StarsAge_Model1.txt')

# %%
# OLD direct from gadget snaps. Needed to adjust the ages (0.69-age)/0.7*1000
#idxNew2 = np.where(LMCage2 > 0)# these are formed in past Gyr 
#idxOld2 = np.where(LMCage2 < 0) # These were the ICs (older than 6 Gyr in model 2 and 5 Gyr in Model 1)
#idxMid2 = np.where(LMCage2 == 0)# these were formed over 1-6 Gyr ago in Model 2 and 1-5 Gyr ago in Model 1
# i.e (LMC-SMC interactions) pre-LMC infall

# Adjusted Age Files 
# MODEL 2 
idxNew2 = np.where(LMCage2 < 4000)# these are formed in past Gyr 
idxOld2 = np.where(LMCage2 >4000) # These were the ICs, given age of 6000 but should be 5000 in Model 1 really
idxMid2 = np.where((LMCage2 == 4000))# these were formed over 1-6 Gyr ago in Model 2 
#(LMC-SMC interactions) and 1-5 Gyr in Model 1. given age of 4000 Myr as avg


idxNew0_25Myr_2 = np.where( (LMCage2 >0) & (LMCage2 <25)) 
idxNew25_50Myr_2 = np.where( (LMCage2 >25) & (LMCage2 <50)) 
idxNew50_75Myr_2 = np.where( (LMCage2 >50) & (LMCage2 <75)) 
idxNew75_100Myr_2 = np.where( (LMCage2 >75) & (LMCage2 <100)) 

idxNew100Myr_2 = np.where( (LMCage2 >0) & (LMCage2 <100)) 
idxNew200Myr_2 = np.where( (LMCage2 >100) & (LMCage2 <200)) 
idxNew300Myr_2 = np.where( (LMCage2 >200) & (LMCage2 <300)) 
idxNew800Myr_2 = np.where( (LMCage2 >800) & (LMCage2 < 1000) ) # & (LMCage2 <100))

# %%
#LMCage2_new = copy(LMCage2)
#LMCage2_new = (0.69 - LMCage2_new*0.7/1000)/0.7*1000

# %%
print(len(idxNew2[0])) # these are formed in past Gyr 
print(len(idxOld2[0])) # These were the ICs
print(len(idxMid2[0])) # these were formed over the past 6 Gyr (LMC-SMC interactions)
print(np.max(LMCage2))
# Out:
# 19133
# 1000000
# 315969
# 6000.0

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)

plt.hist2d(LMCpos2[:,0], LMCpos2[:,1], bins=500, norm=LogNorm(), cmap='magma')
plt.colorbar()

# Add axis labels
plt.xlabel('X', fontsize=22)
plt.ylabel('Y', fontsize=22)

#set axis limits
plt.xlim(-20,20)
plt.ylim(-25, -60)

#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
# OLD STARS 

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)

# plot the particle density for M31 
plt.hist2d(LMCpos2[idxOld2[0],0], LMCpos2[idxOld2[0],1], bins=500, norm=LogNorm(), cmap='magma')
plt.colorbar()

# Add axis labels
plt.xlabel('X', fontsize=22)
plt.ylabel('Y', fontsize=22)

#set axis limits
plt.xlim(-20,20)
plt.ylim(-25, -60)

#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
# New STARS 

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)

# plot the particle density for M31 
#plt.hist2d(LMCpos2[idxNew2[0],0], LMCpos2[idxNew2[0],1], bins=500, norm=LogNorm(), cmap='magma')
plt.hist2d(LMCpos2[idxNew100Myr_2[0],0], LMCpos2[idxNew100Myr_2[0],1], bins=500, norm=LogNorm(), cmap='magma')

plt.colorbar()

# Add axis labels
plt.xlabel('X', fontsize=22)
plt.ylabel('Y', fontsize=22)

#set axis limits
plt.xlim(-10,10)
plt.ylim(-30, -50)

#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
# MID STARS 

fig = plt.figure(figsize=(10,10))
ax = plt.subplot(111)

# plot the particle density for M31 
plt.hist2d(LMCpos2[idxMid2[0],0], LMCpos2[idxMid2[0],1], bins=500, norm=LogNorm(), cmap='magma')
plt.colorbar()

# Add axis labels
plt.xlabel('X', fontsize=22)
plt.ylabel('Y', fontsize=22)

#set axis limits
plt.xlim(-20,20)
plt.ylim(-25, -60)

#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
fig = plt.figure(figsize=(15,15))
ax = plt.subplot(111)


plt.scatter(LMCpos2[idxNew100Myr_2[0],0],LMCpos2[idxNew100Myr_2[0],1],c=LMCage2[idxNew100Myr_2[0]]) # , norm=matplotlib.colors.LogNorm())


#colorbar
cbar = plt.colorbar()
cbar.set_label('Age (Myr)', size=22)


#labels
plt.ylabel('X', fontsize=22)
plt.xlabel('Y', fontsize=22)

plt.figtext(0.55, 0.83, 'Model 2', fontsize=22)

#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size
#set axis limits
#plt.xlim(100,-150)
#plt.ylim(-50,50)

#set axis limits
#plt.xlim(0,150)
#plt.ylim(-250,0)
#set axis limits
#plt.xlim(-20,20)
#plt.ylim(-25, -60)


#def yfunc2(xx):
#    return 1.5 + 0*xx
#a = np.arange(0,13.0,0.1)
#plt.plot(a,yfunc2(a), linewidth=5.0, linestyle='--', c='r')

#plt.figtext(0.63, 0.21, '1.5 Mpc', fontsize=20)#


#adjust tick label font size
label_size = 22
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
fig = plt.figure(figsize=(10,10))

ax = plt.subplot(111)


countsL, binsL, barsL = plt.hist(LMCage2[idxNew2[0]], bins=100, ls='dashed', alpha = 0, color='white', normed=0)
indexL = np.arange(0,100) # make sure bins and counts have the same size 
plt.hist(binsL[indexL], bins=len(binsL[indexL]), weights=countsL[indexL], alpha=0.3, color='blue',label='LMC',edgecolor='b', linewidth=2)

#plt.xlim(-100,1000)
# Out:
# /Users/gurtinabesla/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# (array([178., 188., 269., 189., 282., 237., 320., 267., 289., 320., 253.,
#         189., 165., 237., 211., 216., 220., 170., 218., 174., 203., 142.,
#         232., 268., 140., 284., 211., 225., 152., 212., 209., 193., 205.,
#         171., 130., 112., 110., 146., 110., 102., 110.,  76., 274., 197.,
#         247., 141., 178., 366., 222., 218., 174., 161.,  97., 205., 170.,
#         201., 160., 266., 159., 205., 229., 220., 224., 174., 160., 164.,
#         127., 138., 142.,  79., 141., 145., 178., 282., 177., 176., 164.,
#         153., 204., 232., 220., 167., 206., 159., 195., 183., 217., 263.,
#         203., 170., 174., 199., 140., 183., 147., 170., 190.,  87., 182.,
#         193.]),
#  array([8.37020000e-02, 9.84006585e+00, 1.95964297e+01, 2.93527936e+01,
# ...

# %%
fig = plt.figure(figsize=(15,15))
ax = plt.subplot(111)


plt.scatter(LMCpos2[idxNew100Myr_2[0],0],LMCpos2[idxNew100Myr_2[0],1], label='100 Myr') # , norm=matplotlib.colors.LogNorm())
plt.scatter(LMCpos2[idxNew200Myr_2[0],0],LMCpos2[idxNew200Myr_2[0],1], label='200 Myr') # , norm=matplotlib.colors.LogNorm())
plt.scatter(LMCpos2[idxNew300Myr_2[0],0],LMCpos2[idxNew300Myr_2[0],1], label='200 Myr') # , norm=matplotlib.colors.LogNorm())


#colorbar
#cbar = plt.colorbar()
#cbar.set_label('Age (Myr)', size=22)


#labels
plt.ylabel('X', fontsize=22)
plt.xlabel('Y', fontsize=22)

plt.figtext(0.55, 0.83, 'Model 2', fontsize=22)

#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size
#set axis limits
#plt.xlim(100,-150)
#plt.ylim(-50,50)

#set axis limits
#plt.xlim(0,150)
#plt.ylim(-250,0)
#set axis limits
#plt.xlim(-20,20)
#plt.ylim(-25, -60)


#def yfunc2(xx):
#    return 1.5 + 0*xx
#a = np.arange(0,13.0,0.1)
#plt.plot(a,yfunc2(a), linewidth=5.0, linestyle='--', c='r')

#plt.figtext(0.63, 0.21, '1.5 Mpc', fontsize=20)#


#adjust tick label font size
label_size = 22
plt.rcParams.update({'font.size': 15})
plt.legend(loc='upper right')
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size

# %%
fig = plt.figure(figsize=(15,15))
ax = plt.subplot(111)


plt.scatter(LMCpos2[idxNew0_25Myr_2[0],0],LMCpos2[idxNew0_25Myr_2[0],1], label='0-25 Myr') # , norm=matplotlib.colors.LogNorm())
plt.scatter(LMCpos2[idxNew25_50Myr_2[0],0],LMCpos2[idxNew25_50Myr_2[0],1], label='25-50 Myr') # , norm=matplotlib.colors.LogNorm())
plt.scatter(LMCpos2[idxNew50_75Myr_2[0],0],LMCpos2[idxNew50_75Myr_2[0],1], label='50-75 Myr') # , norm=matplotlib.colors.LogNorm())
plt.scatter(LMCpos2[idxNew75_100Myr_2[0],0],LMCpos2[idxNew75_100Myr_2[0],1], label='75-100 Myr') # , norm=matplotlib.colors.LogNorm())


#colorbar
#cbar = plt.colorbar()
#cbar.set_label('Age (Myr)', size=22)


#labels
plt.ylabel('X', fontsize=22)
plt.xlabel('Y', fontsize=22)

plt.figtext(0.55, 0.83, 'Model 2', fontsize=22)

#adjust tick label font size
label_size = 15
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size
#set axis limits
#plt.xlim(100,-150)
#plt.ylim(-50,50)

#set axis limits
#plt.xlim(0,150)
#plt.ylim(-250,0)
#set axis limits
#plt.xlim(-20,20)
#plt.ylim(-25, -60)


#def yfunc2(xx):
#    return 1.5 + 0*xx
#a = np.arange(0,13.0,0.1)
#plt.plot(a,yfunc2(a), linewidth=5.0, linestyle='--', c='r')

#plt.figtext(0.63, 0.21, '1.5 Mpc', fontsize=20)#


#adjust tick label font size
label_size = 22
plt.rcParams.update({'font.size': 15})
plt.legend(loc='upper right')
matplotlib.rcParams['xtick.labelsize'] = label_size 
matplotlib.rcParams['ytick.labelsize'] = label_size
